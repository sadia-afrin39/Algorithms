# %% [markdown]
# <a href="https://colab.research.google.com/github/sadia-afrin39/Algorithms/blob/master/Sorts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=[23,45,56,1,34,49,7,12]

def insertionSort(A):
  length=len(A)

  for j in range(1,length):
    key=A[j]
    i=j-1
    while i>-1 and A[i]>key:
      A[i+1]=A[i]
      i=i-1
    A[i+1]=key



  # write down the algo of selection sort
def selectionSort(A):  
  for i in range(len(A)): 

    min_idx = i 
    for j in range(i+1, len(A)): 
        if A[min_idx] > A[j]: 
            min_idx = j 
         
    A[i], A[min_idx] = A[min_idx], A[i] 



    # write down the algo of bubble sort
def bubbleSort(A):
    n = len(A)
 

    for i in range(n):
 
       
        for j in range(0, n-i-1):
 
            if A[j] > A[j+1] :
                A[j], A[j+1] = A[j+1], A[j]
 


  # write down the algo of merge sort
def mergeSort(A): 
	if len(A) >1: 
		mid = len(A)//2 
		L = A[:mid] 
		R = A[mid:] 

		mergeSort(L)
		mergeSort(R) 
		i = j = k = 0
		
		while i < len(L) and j < len(R): 
			if L[i] < R[j]: 
				A[k] = L[i] 
				i+=1
			else: 
				A[k] = R[j] 
				j+=1
			k+=1
		
		
		while i < len(L): 
			A[k] = L[i] 
			i+=1
			k+=1
		
		while j < len(R): 
			A[k] = R[j] 
			j+=1
			k+=1


  # write down the algo of counting sort
def countingsort(array1, max_val):
    m = max_val + 1
    count = [0] * m                
    
    for a in array1:
        count[a] += 1             
    i = 0
    for a in range(m):            
        for c in range(count[a]):  
            array1[i] = a
            i += 1
    return array1
 


insertionSort(A)
print("InsertionSort: ",A)

selectionSort(A)
print("SelectionSort: ",A)

bubbleSort(A)
print("BubbleSort: ",A)

mergeSort(A)
print("MergeSort: ",A)

countingsort(A,56)
print("CountingSort: ",A)
# Out:
# InsertionSort:  [1, 7, 12, 23, 34, 45, 49, 56]
# SelectionSort:  [1, 7, 12, 23, 34, 45, 49, 56]
# BubbleSort:  [1, 7, 12, 23, 34, 45, 49, 56]
# MergeSort:  [1, 7, 12, 23, 34, 45, 49, 56]
# CountingSort:  [1, 7, 12, 23, 34, 45, 49, 56]
